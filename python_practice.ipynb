# %% [markdown]
# <a href="https://colab.research.google.com/github/madhav6186/python/blob/main/python_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Write a Python program to input a number and check whether it is positive, negative, or zero.

# %%
n=int(input("Enter a number:"))
if n>0:
  print("The number is positive")
elif n<0:
  print("The number is negative")
else:
  print("The number is zero")

# %% [markdown]
# 2. write a Python program to input an integer and display whether it is even or odd.

# %%
n=int(input("entre a number"))
if n<0:
  print("+ve")
elif n>0:
  print("-ve")
else:
  print("zero")

# %% [markdown]
# 3. Write a Python program to input a person's age and display:
# ●	"Eligible to vote" if age is 18 or above
# ●	"Not eligible to vote" otherwise.

# %%
age=int(input("entre your age"))
if age<=18:
  print("not eligible to vote")
else:
  print("eligible to vote")

# %% [markdown]
# 4. Write a program to input two numbers and display the greater number.

# %%
n1=int(input("entre a number"))
n2=int(input("entre 2nd number"))
if n1>n2:
  print(n1,"is greater")
else:
  print(n2,"is greater")

# %% [markdown]
# 5. Write a Python program to input three numbers and find the largest number.

# %%
n1=int(input("entre a number"))
n2=int(input("entre 2nd number"))
n3=int(input("entre 3rd number"))
if n1>=n2 and n1>=n3:
  print(n1,"is greater")
elif n2>=n1 and n2>=n3:
  print(n2,"is greater")
else:
  print(n3,"is greater")

# %% [markdown]
# 5. Input a student's mark and display:
# ●	"Pass" if mark is 40 or above
# ●	"Fail" otherwise.

# %%
mark=int(input("entre your mark "))
if mark>=40:
  print("pass")
else:
  print("fail")
# Out:
# entre your mark40
# pass

# %% [markdown]
# 6. Write a program to input a number and check whether it is divisible by 5 or not.

# %%
n = int(input("enter a number "))
if n% 5 == 0:
    print("number is divisible by 5")
else:
    print("number is not divisible by 5")

# %% [markdown]
# 7. Input the temperature and display:
# ●	"Cold" if temperature is below 20
# ●	"Normal" if temperature is between 20 and 30
# ●	"Hot" if temperature is above 30.

# %%
temp=int(input("entre temperature"))
if temp<20:
  print("cold")
elif temp>=20 and temp<=30:
  print("normal")
else:
  print("hot")
