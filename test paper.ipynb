# %% [markdown]
# <a href="https://colab.research.google.com/github/madhav6186/python/blob/main/test%20paper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  check the username and password is correct or invalid

# %%
user = "madhav6186"
password = 2006
u = input("Enter your username: ")
p = int(input("Enter your password: "))

if  p == password:
    print("login successful")
else:
    print("login failed")
# Out:
# Enter your username: madhav6186
# Enter your password: 2006
# login successful

# %% [markdown]
# chech the balance

# %%
w=int(input("entre your amount"))
b=500
if w<=b:
  print("payment successful")
else:
  print("insufficient balance")
# Out:
# entre your amount499
# payment successful

# %% [markdown]
# restaurants bill

# %%
amount = float(input("enter the food amount: "))
scharge = amount * 0.05
tbill = amount + scharge


if tbill > 2000:
    discount=tbill*0.10
else:
    discount=0
famount = tbill - discount
print(f"Food Amount {amount}")
print(f"Service Charge {scharge}")
print(f"Discount {discount}")
print(f"Final Amount {famount}")
# Out:
# enter the food amount: 1000
# Food Amount 1000.0
# Service Charge 50.0
# Discount 0
# Final Amount 1050.0
