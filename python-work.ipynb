# %% [markdown]
# Digital Introduction Card

# %%
recharge = int(input("enter ramount: "))
gstpercentage = float(input("enter gst percentage: "))

gst = recharge * gstpercentage / 100
finalamount = recharge + gst

print("GST =", gst)
print("Final amount =", finalamount)

# %% [markdown]
# Age Calculator

# %%
birthyear = int(input("enter your birth year "))

currentyear = 2026
age = currentyear - birthyear

print("age is ", age)

# %% [markdown]
# Bill Calculator

# %%
p= int(input("enter price : "))
q= int(input("enter quantity: "))
t=p*q
print("Total bill = ", t)

# %% [markdown]
# Mobile Recharge Calculator

# %%
recharge = int(input("enter ramount: "))
gstpercentage = float(input("enter gst percentage: "))

gst = recharge * gstpercentage / 100
finalamount = recharge + gst

print("GST =", gst)
print("Final amount =", finalamount)

# %% [markdown]
# Temperature Converter

# %%
c= float(input("enter temperature"))

f = (c*9/5)+32

print(f)

# %% [markdown]
# Simple Interest Calculator

# %%
principal = float(input("enter amount: "))
rate = float(input("enter rate: "))
time = float(input("enter time: "))

interest = (principal * rate * time) / 100
total_amount = principal + interest

print("Simple Interest =", interest)
print("Total Amount =", total_amount)

# %% [markdown]
# Travel Distance Calculator

# %%
speed = int(input("enter speed "))
time = int(input("enter travel time "))

distance = speed*time

print("distance travel =", distance)

# %% [markdown]
# BMI Calculator

# %%
h=float(input("enter height "))
w= int(input("enter weight : "))

bmi = w/(h*h)

print("Your BMI =", bmi)

# %% [markdown]
# Electricity Bill Estimator

# %%
units = int(input("enter units consumed: "))
cost = int(input("enter cost per unit: "))

bill = units*cost

print(" electricity bill =", bill)

# %% [markdown]
# Shopping Receipt

# %%
n1 = input("enter 1st product ")
p1 = float(input("enter price: "))

n2 = input("enter 2nd product : ")
p2 = float(input("enter price: "))

n3 = input("enter 3rd product ")
p3 = float(input("enter price: "))

t= p1 + p2 + p3

print("Product 1:", n1, p1)
print("Product 2:", n2, p2)
print("Product 3:", n3, p3)

print("Total =",t)
